# %% [markdown]
# ### **Cross Validation Analysis**

# %%
import os
import sys
from pathlib import Path
import matplotlib.pyplot as plt

project_root = Path(os.getcwd()).resolve().parent

sys.path.append(str(project_root))

from src.utils import read_processed_data, config_loader, get_logger


log = get_logger()
config = config_loader()
path_svc = os.path.join(project_root, config['cv_result'], 'svc_results.csv')
path_knn = os.path.join(project_root, config['cv_result'], 'knn_results.csv')
path_rf = os.path.join(project_root, config['cv_result'], 'rf_results.csv')
path_xgb = os.path.join(project_root, config['cv_result'], 'xgb_results.csv')

cv_result = read_processed_data(path=path_svc, log=log)
cv_result = cv_result.sort_values(by='param_C')
# Out:
# 2025-07-08 02:17:34.332 | INFO     | src.utils:read_processed_data:56 - Data read successfully from /home/runner/work/aqi-healthy-air/aqi-healthy-air/cv_results/svc_results.csv

# %%
# Display basic information about the cv_result DataFrame
print("Shape of cv_result:", cv_result.shape)
print("\nFirst 5 rows:")
print(cv_result.head())

print("\nSummary statistics:")
print(cv_result.describe(include='all'))

# Check for missing values
print("\nMissing values per column:")
print(cv_result.isnull().sum())
# Out:
# Shape of cv_result: (10, 49)
#
# First 5 rows:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 7     217.636707    181.577594        11.419946        5.486037          rbf
# 9     226.878623    196.600038         9.735166        3.815683          rbf
# 5     234.913996    195.441185        11.963663        5.587273          rbf
# 3     250.879930    214.921485        12.451949        5.928290          rbf
# 4      41.583274     27.891457         4.189823        1.633562          rbf
#
#             param_gamma param_class_weight   param_C  \
# 7                  auto           balanced  0.010000
# 9                  auto                NaN  0.077426
# 5   0.15848931924611143           balanced  0.215443
# 3                   1.0           balanced  0.215443
# 4  0.003981071705534973           balanced  0.599484
#
#                                               params  split0_test_accuracy  \
# 7  {'kernel': 'rbf', 'gamma': 'auto', 'class_weig...              0.200000
# 9  {'kernel': 'rbf', 'gamma': 'auto', 'class_weig...              0.200000
# 5  {'kernel': 'rbf', 'gamma': 0.15848931924611143...              0.200000
# 3  {'kernel': 'rbf', 'gamma': 1.0, 'class_weight'...              0.200000
# 4  {'kernel': 'rbf', 'gamma': 0.00398107170553497...              0.734188
#
#    ...  std_test_precision  rank_test_precision  split0_test_roc_auc  \
# 7  ...            0.045790                    9             0.099566
# 9  ...            0.065562                    8             0.903486
# 5  ...            0.112452                    6             0.635655
# 3  ...            0.017486                   10             0.482458
# 4  ...            0.119422                    5             0.957493
#
#    split1_test_roc_auc  split2_test_roc_auc  split3_test_roc_auc  \
# 7             0.041118             0.073621             0.304839
# 9             0.930489             0.944253             0.925610
# 5             0.864062             0.719242             0.882546
# 3             0.382872             0.363632             0.311931
# 4             0.991230             0.989342             0.959683
#
#    split4_test_roc_auc  mean_test_roc_auc  std_test_roc_auc  rank_test_roc_auc
# 7             0.328780           0.169585          0.121862                 10
# 9             0.893691           0.919506          0.018403                  6
# 5             0.807453           0.781792          0.092571                  7
# 3             0.445481           0.397275          0.060337                  9
# 4             0.936859           0.966921          0.020682                  3
#
# [5 rows x 49 columns]
#
# Summary statistics:
#         mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# count       10.000000     10.000000        10.000000       10.000000
# unique            NaN           NaN              NaN             NaN
# top               NaN           NaN              NaN             NaN
# freq              NaN           NaN              NaN             NaN
# mean       156.321873    138.755153         6.693439        2.875907
# std        168.503613    164.792630         4.750110        2.219280
# min          6.598027      4.755867         1.055715        0.497746
# 25%         18.141213     12.464211         2.366832        0.945582
# 50%        129.609990    104.734525         6.940146        2.459777
# 75%        232.905153    196.310325        10.998751        5.068449
# max        528.975781    528.700822        12.451949        5.928290
#
#        param_kernel param_gamma param_class_weight     param_C  \
# count            10          10                  5   10.000000
# unique            1           6                  1         NaN
# top             rbf        auto           balanced         NaN
# freq             10           2                  5         NaN
# mean            NaN         NaN                NaN   27.466217
# std             NaN         NaN                NaN   40.882500
# min             NaN         NaN                NaN    0.010000
# 25%             NaN         NaN                NaN    0.215443
# 50%             NaN         NaN                NaN    1.133792
# 75%             NaN         NaN                NaN   35.938137
# max             NaN         NaN                NaN  100.000000
#
#                                                    params  \
# count                                                  10
# unique                                                 10
# top     {'kernel': 'rbf', 'gamma': 'auto', 'class_weig...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#         split0_test_accuracy  ...  std_test_precision  rank_test_precision  \
# count              10.000000  ...           10.000000             10.00000
# unique                   NaN  ...                 NaN                  NaN
# top                      NaN  ...                 NaN                  NaN
# freq                     NaN  ...                 NaN                  NaN
# mean                0.501616  ...            0.100282              5.50000
# std                 0.320123  ...            0.045437              3.02765
# min                 0.200000  ...            0.017486              1.00000
# 25%                 0.200000  ...            0.070593              3.25000
# 50%                 0.467094  ...            0.115269              5.50000
# 75%                 0.797363  ...            0.133931              7.75000
# max                 0.875621  ...            0.157663             10.00000
#
#         split0_test_roc_auc  split1_test_roc_auc  split2_test_roc_auc  \
# count             10.000000            10.000000            10.000000
# unique                  NaN                  NaN                  NaN
# top                     NaN                  NaN                  NaN
# freq                    NaN                  NaN                  NaN
# mean               0.751285             0.785297             0.770210
# std                0.304020             0.329368             0.322425
# min                0.099566             0.041118             0.073621
# 25%                0.552701             0.713341             0.672239
# 50%                0.930489             0.960316             0.965062
# 75%                0.972655             0.994500             0.988738
# max                0.988918             0.997783             0.992496
#
#         split3_test_roc_auc  split4_test_roc_auc  mean_test_roc_auc  \
# count             10.000000            10.000000          10.000000
# unique                  NaN                  NaN                NaN
# top                     NaN                  NaN                NaN
# freq                    NaN                  NaN                NaN
# mean               0.788832             0.788630           0.776851
# std                0.257507             0.225808           0.283432
# min                0.304839             0.328780           0.169585
# 25%                0.816852             0.738981           0.698823
# 50%                0.908648             0.913764           0.940786
# 75%                0.930591             0.937375           0.966164
# max                0.959683             0.943421           0.968369
#
#         std_test_roc_auc  rank_test_roc_auc
# count          10.000000           10.00000
# unique               NaN                NaN
# top                  NaN                NaN
# freq                 NaN                NaN
# mean            0.051590            5.50000
# std             0.037102            3.02765
# min             0.018403            1.00000
# 25%             0.022001            3.25000
# 50%             0.033910            5.50000
# 75%             0.081302            7.75000
# max             0.121862           10.00000
#
# [11 rows x 49 columns]
#
# Missing values per column:
# mean_fit_time            0
# std_fit_time             0
# mean_score_time          0
# std_score_time           0
# param_kernel             0
# param_gamma              0
# param_class_weight       5
# param_C                  0
# params                   0
# split0_test_accuracy     0
# split1_test_accuracy     0
# split2_test_accuracy     0
# split3_test_accuracy     0
# split4_test_accuracy     0
# mean_test_accuracy       0
# std_test_accuracy        0
# rank_test_accuracy       0
# split0_test_f1           0
# split1_test_f1           0
# split2_test_f1           0
# split3_test_f1           0
# split4_test_f1           0
# mean_test_f1             0
# std_test_f1              0
# rank_test_f1             0
# split0_test_recall       0
# split1_test_recall       0
# split2_test_recall       0
# split3_test_recall       0
# split4_test_recall       0
# mean_test_recall         0
# std_test_recall          0
# rank_test_recall         0
# split0_test_precision    0
# split1_test_precision    0
# split2_test_precision    0
# split3_test_precision    0
# split4_test_precision    0
# mean_test_precision      0
# std_test_precision       0
# rank_test_precision      0
# split0_test_roc_auc      0
# split1_test_roc_auc      0
# split2_test_roc_auc      0
# split3_test_roc_auc      0
# split4_test_roc_auc      0
# mean_test_roc_auc        0
# std_test_roc_auc         0
# rank_test_roc_auc        0
# dtype: int64

# %%
parameter = ['mean_test_f1', 'mean_test_accuracy', 'mean_test_roc_auc']

for param in parameter:
        
    plt.figure(figsize=(8, 5))
    plt.plot(cv_result['param_C'], cv_result[param], marker='o')
    plt.xscale('log')
    plt.xlabel('C (Regularizaton Parameter)')
    plt.title(f'SVC: {param.replace("mean_test_", "").title()} vs. C')
    plt.ylabel(f'Mean CV {param.replace("mean_test_", "").title()}')
    plt.grid(True)
    plt.savefig(f'svc_{param.replace("mean_test_", "").title()}_vs_C.png', dpi=500)
    plt.show()

# %%
#  KNN Plot..
cv_result_knn = read_processed_data(path=path_knn, log=log)
cv_result_knn = cv_result_knn.sort_values(by="param_n_neighbors")

metrics = [
    ('mean_test_accuracy', 'Accuracy'),
    ('mean_test_f1', 'F1 Score'),
    ('mean_test_recall', 'Recall'),
    ('mean_test_precision', 'Precision'),
    ('mean_test_roc_auc', 'ROC-AUC')
]

for metric, label in metrics:
    plt.figure(figsize=(8, 5))
    plt.plot(cv_result_knn['param_n_neighbors'], cv_result_knn[metric], marker='o')
    plt.xlabel('Number of Neighbors (k)')
    plt.ylabel(f'Mean CV {label}')
    plt.title(f'KNN: {label} vs. Number of Neighbors')
    plt.grid(True)
    plt.savefig(f'knn_{metric}_vs_k.png', dpi=500)
    plt.show()
# Out:
# 2025-07-08 02:17:36.820 | INFO     | src.utils:read_processed_data:56 - Data read successfully from /home/runner/work/aqi-healthy-air/aqi-healthy-air/cv_results/knn_results.csv

# %%
# XGBoost Plot..
cv_result_xgb = read_processed_data(path=path_xgb, log=log)

metrics = [
    ('accuracy', 'mean_test_accuracy'),
    ('f1', 'mean_test_f1'),
    ('recall', 'mean_test_recall'),
    ('precision', 'mean_test_precision'),
    ('roc_auc', 'mean_test_roc_auc')
]

params = ['param_n_estimators', 'param_max_depth', 'param_learning_rate']  
for x_param in params:
    cv_result_xgb = cv_result_xgb.sort_values(by=x_param)
    for label, test_metric in metrics:
        plt.figure(figsize=(8, 5))
        plt.plot(cv_result_xgb[x_param], cv_result_xgb[test_metric], marker='o', label='Mean Test')
        plt.xlabel(x_param.replace('param_', '').replace('_', ' ').title())
        plt.ylabel(label.title())
        plt.title(f'XGBoost: Test {label.title()} vs. {x_param.replace("param_", "").title()}')
        plt.legend()
        plt.grid(True)
        plt.savefig(f'xgb_{label}_train_test_vs_{x_param}.png', dpi=500)
        plt.show()
# Out:
# 2025-07-08 02:17:39.646 | INFO     | src.utils:read_processed_data:56 - Data read successfully from /home/runner/work/aqi-healthy-air/aqi-healthy-air/cv_results/xgb_results.csv

# %%
# Random Forest Plot..
cv_result_rf = read_processed_data(path=path_rf, log=log)
cv_result_rf = cv_result_rf.sort_values(by='param_n_estimators')

metrics = [
    ('mean_test_accuracy', 'Accuracy'),
    ('mean_test_f1', 'F1 Score'),
    ('mean_test_recall', 'Recall'),
    ('mean_test_precision', 'Precision'),
    ('mean_test_roc_auc', 'ROC-AUC')
]

for metric, label in metrics:
    plt.figure(figsize=(8, 5))
    plt.plot(cv_result_rf['param_n_estimators'], cv_result_rf[metric], marker='o')
    plt.xlabel('Number of Trees (n_estimators)')
    plt.ylabel(f'Mean CV {label}')
    plt.title(f'RF: {label} vs. Number of Trees')
    plt.grid(True)
    plt.savefig(f'rf_{metric}_vs_estimators.png', dpi=500)
    plt.show()
# Out:
# 2025-07-08 02:17:48.284 | INFO     | src.utils:read_processed_data:56 - Data read successfully from /home/runner/work/aqi-healthy-air/aqi-healthy-air/cv_results/rf_results.csv
